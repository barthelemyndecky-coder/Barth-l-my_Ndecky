# %%
# !pip install giotto-tda
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 28.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 78.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.9/457.9 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
from gtda.homology import VietorisRipsPersistence
from gtda.diagrams import PersistenceEntropy, Amplitude, BettiCurve

# %% [markdown]
# # Active vs Inactive Substances: qHTS Assay for Inhibitors and Substrates of Cytochrome P450 3A4

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("PubChem_active.csv")
df2 = pd.read_csv("PubChem_inactive.csv")
df1.head()
# Out:
#    Compound_CID                                               Name  \
# 0       3233816  N-[3-[4-(cyclopropylamino)quinazolin-2-yl]phen...
# 1       3233844  (4-methoxyphenyl)-[(5S)-2-pyridin-2-yl-2,7-dia...
# 2       3233843  6-(3-methoxyphenyl)-N-[(5-methylpyrazin-2-yl)m...
# 3       3233839  N-[(2-methoxyphenyl)methyl]-6-pyridin-3-ylpyri...
# 4       3233837  6-(3,5-Difluorophenyl)-2-(4-methoxyphenoxy)-8-...
#
#                                  Synonyms  Molecular_Weight Molecular_Formula  \
# 0  NCGC00011236|CHEMBL1490477|PCOP-408833            354.40       C18H18N4O2S
# 1  NCGC00011264|CHEMBL1611806|PCOP-417927            351.40        C21H25N3O2
# 2  NCGC00011263|CHEMBL1433559|PCOP-417822            357.40         C21H19N5O
# 3  NCGC00011259|CHEMBL1377727|PCOP-416841            292.33         C17H16N4O
# 4  NCGC00011257|CHEMBL1525456|PCOP-415574            396.30      C20H14F2N4O3
#
#    Polar_Area  Complexity  XLogP  Heavy_Atom_Count  H-Bond_Donor_Count  ...  \
# ...

# %%
my_data = pd.read_csv("drugs_combined.csv")
my_data.head()
# Out:
#                                                 Name  \
# 0  N-[3-[4-(cyclopropylamino)quinazolin-2-yl]phen...
# 1  (4-methoxyphenyl)-[(5S)-2-pyridin-2-yl-2,7-dia...
# 2  6-(3-methoxyphenyl)-N-[(5-methylpyrazin-2-yl)m...
# 3  N-[(2-methoxyphenyl)methyl]-6-pyridin-3-ylpyri...
# 4  6-(3,5-Difluorophenyl)-2-(4-methoxyphenoxy)-8-...
#
#                                               SMILES  target
# 0  CS(=O)(=O)NC1=CC=CC(=C1)C2=NC3=CC=CC=C3C(=N2)N...       0
# 1  COC1=CC=C(C=C1)C(=O)N2CCC[C@]3(C2)CCN(C3)C4=CC...       0
# 2  CC1=CN=C(C=N1)CNC2=NC=NC3=C2C=C(C=C3)C4=CC(=CC...       0
# 3            COC1=CC=CC=C1CNC2=NC=NC(=C2)C3=CN=CC=C3       0
# 4  CN1C2=NC(=NC=C2N=C(C1=O)C3=CC(=CC(=C3)F)F)OC4=...       0

# %%
my_data["Name_sp"] = my_data["Name"].str.split(']').str[-1].str.strip()
my_data.head(8)
# Out:
#                                                 Name  \
# 0  N-[3-[4-(cyclopropylamino)quinazolin-2-yl]phen...
# 1  (4-methoxyphenyl)-[(5S)-2-pyridin-2-yl-2,7-dia...
# 2  6-(3-methoxyphenyl)-N-[(5-methylpyrazin-2-yl)m...
# 3  N-[(2-methoxyphenyl)methyl]-6-pyridin-3-ylpyri...
# 4  6-(3,5-Difluorophenyl)-2-(4-methoxyphenoxy)-8-...
# 5  5-(2-chlorophenyl)-N-[2-(5-methoxy-1H-indol-3-...
# 6  N-[3-[4-(pyridin-4-ylamino)quinazolin-2-yl]phe...
# 7      N-benzyl-2-(2-methoxyphenyl)pyrimidin-4-amine
#
#                                               SMILES  target  \
# 0  CS(=O)(=O)NC1=CC=CC(=C1)C2=NC3=CC=CC=C3C(=N2)N...       0
# 1  COC1=CC=C(C=C1)C(=O)N2CCC[C@]3(C2)CCN(C3)C4=CC...       0
# 2  CC1=CN=C(C=N1)CNC2=NC=NC3=C2C=C(C=C3)C4=CC(=CC...       0
# 3            COC1=CC=CC=C1CNC2=NC=NC(=C2)C3=CN=CC=C3       0
# 4  CN1C2=NC(=NC=C2N=C(C1=O)C3=CC(=CC(=C3)F)F)OC4=...       0
# 5   COC1=CC2=C(C=C1)NC=C2CCNC3=NC=NC=C3C4=CC=CC=C4Cl       0
# ...

# %%
my_names = my_data["Name_sp"].values
my_names = list(my_names)
my_smiles = my_data["SMILES"].values

# %%
# !pip install rdkit

# %%
# For Jupyter Notebook, use this quick-start code:
from rdkit import Chem
from rdkit.Chem import Draw
import networkx as nx
import matplotlib.pyplot as plt

# Quick visualization of SMILES
def quick_visualize(smiles_list, names=None):
    if names is None:
        names = [f"Compound {i+1}" for i in range(len(smiles_list))]

    mols = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            mols.append(mol)

    img = Draw.MolsToGridImage(mols, legends=names, molsPerRow=2)
    return img

# %% [markdown]
# # Active substances: Inhibitors and Substrates of Cytochrome P450 3A4

# %%
quick_visualize(my_smiles[1000:1004], my_names[1000:1004])

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from rdkit import Chem
from rdkit.Chem import AllChem, Draw

import matplotlib.pyplot as plt
import networkx as nx
from rdkit import Chem
from rdkit.Chem import AllChem, Draw

def plot_simple_molecule_graph(smiles, save_path=None, figsize=(8, 6)):
    """
    Convert SMILES to graph and plot it.

    Args:
        smiles (str): SMILES string
        save_path (str): Path to save the plot (e.g., 'molecule.png')
        figsize (tuple): Figure size

    Returns:
        tuple: (fig, axes, G) - matplotlib figure, axes, and NetworkX graph
    """
    # Convert SMILES to molecule
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        print(f"Invalid SMILES: {smiles}")
        return None

    # Generate 2D coordinates
    mol = Chem.AddHs(mol)  # Add hydrogens for better visualization
    AllChem.Compute2DCoords(mol)

    # Create graph
    G = nx.Graph()
    pos = {}  # Store node positions

    # Add atoms as nodes with positions
    for atom in mol.GetAtoms():
        idx = atom.GetIdx()
        G.add_node(idx, symbol=atom.GetSymbol())

        # Get 2D coordinates
        conf = mol.GetConformer()
        pos[idx] = (conf.GetAtomPosition(idx).x, conf.GetAtomPosition(idx).y)

    # Add bonds as edges
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        G.add_edge(i, j)

    # Create plot
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)

    # Plot 1: NetworkX graph
    labels = {i: G.nodes[i]['symbol'] for i in G.nodes()}

    nx.draw(G, pos, ax=ax1, with_labels=True, labels=labels,
            node_color='lightblue', node_size=500,
            font_size=10, font_weight='bold',
            edge_color='gray', width=2)

    ax1.set_title(f"Graph Representation\n{smiles}")
    ax1.axis('equal')

    # Plot 2: RDKit structure
    mol_no_h = Chem.RemoveHs(mol)  # Remove hydrogens for cleaner view
    img = Draw.MolToImage(mol_no_h, size=(300, 300))
    ax2.imshow(img)
    ax2.axis('off')
    ax2.set_title("Chemical Structure")

    plt.tight_layout()

    # Save plot if path is provided
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {save_path}")

    plt.show()

    return fig, (ax1, ax2), G

# %%
save_path = "smiles2graph_n2.jpg"
plot_simple_molecule_graph(my_smiles[500], save_path)
# Out:
# Plot saved to: smiles2graph_n2.jpg
# (<Figure size 800x600 with 2 Axes>,
#  (<Axes: title={'center': 'Graph Representation\nCOC1=CC=CC(=C1)NC2=NC=C3C(=N2)N(C(=O)C=N3)CC4=CC=CS4'}>,
#   <Axes: title={'center': 'Chemical Structure'}>),
#  <networkx.classes.graph.Graph at 0x7cc542e96d20>)

# %% [markdown]
# # Inactive substances: Inhibitors and Substrates of Cytochrome P450 3A4

# %%
quick_visualize(my_smiles[6000:6004], my_names[6000:6004])

# %% [markdown]
# # Topological and Geometrical features:
# * Spectral features
#     * eigenvalues of weighted zero and 1-Laplacians (look up the library called toponetx for the 1-Laplacians eigenvalues)
#   * spectral range
#   * algebraic connectivity
# * Persistent entropy
# * Carlsson Coordinates : The formulas look like Persistent entropy
# * Amplitudes metrics:
#     * Wasserstein
#     * Bottleneck
#     * Landscape
# * Graph statistics:
#     * transitivity
#     * mean degree, max degree, etc.
#     * cycle lengths
#     * diameter and average path length

# %% [markdown]
# # For zero Laplacian, you can compute first 5 smallest non-zero eigenvalues
# # For 1-Laplacian, compute first 5 smallest non-zero eigenvalues

# %% [markdown]
# # Training (Scaffold-split) with topological and geometrical features

# %%
import numpy as np
import networkx as nx
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import eigsh
from scipy.linalg import eigh
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
import seaborn as sns
#from new_features import  DiscriminativeFeatureGenerator
#from enhanced_features import DiscriminativeFeatureGenerator
from feature_gen import DiscriminativeFeatureGenerator
import warnings

warnings.filterwarnings('ignore')

# Try to import TopoModelX, but provide fallbacks
TOPONETX_AVAILABLE = False
try:
    import toponetx as tnx
    TOPONETX_AVAILABLE = True
    print("✓ TopoModelX successfully imported")
except ImportError as e:
    print(f"✗ TopoModelX not available: {e}")
    print("  Using fallback methods for 1-Laplacian computation")
# Out:
# ✗ TopoModelX not available: No module named 'toponetx'
#   Using fallback methods for 1-Laplacian computation

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import random

# ======================================================================
# 1. SCAFFOLD SPLITTING
# ======================================================================
def compute_scaffold(smiles):
    """Return Murcko scaffold SMILES; return None for invalid SMILES"""
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            return None
        scaffold = MurckoScaffold.GetScaffoldForMol(mol)
        return Chem.MolToSmiles(scaffold)
    except:
        return None


def scaffold_split(df, test_size=0.2, random_state=36):
    scaffolds = {}
    for idx, s in enumerate(df["SMILES"]):
        scaffold = compute_scaffold(s)
        if scaffold is None:
            scaffold = f"NOSCAFFOLD_{idx}"
        scaffolds.setdefault(scaffold, []).append(idx)

    scaffold_groups = list(scaffolds.values())

    # Shuffle scaffold groups reproducibly
    rng = random.Random(random_state)
    rng.shuffle(scaffold_groups)

    n_total = len(df)
    n_test_target = int(test_size * n_total)

    test_idx = []
    train_idx = []
    running_count = 0

    for group in scaffold_groups:
        if running_count < n_test_target:
            test_idx.extend(group)
            running_count += len(group)
        else:
            train_idx.extend(group)

    return train_idx, test_idx


# ======================================================================
# 2. GRAPH CONVERTER (now also descriptor extractor)
# ======================================================================
class SMILESToGraphConverter:
    """Convert SMILES strings to adjacency matrices and extract RDKit descriptors"""

    def __init__(self, max_atoms=100):
        self.max_atoms = max_atoms

    def smiles_to_adjacency(self, smiles):
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return np.zeros((self.max_atoms, self.max_atoms))

            mol = Chem.AddHs(mol)
            n_atoms = min(mol.GetNumAtoms(), self.max_atoms)

            adjacency = np.zeros((self.max_atoms, self.max_atoms))

            for i in range(n_atoms):
                atom_i = mol.GetAtomWithIdx(i)
                adjacency[i, i] = atom_i.GetAtomicNum() / 10.0  # Normalize atom numbers

                for j in range(i + 1, n_atoms):
                    bond = mol.GetBondBetweenAtoms(i, j)
                    if bond:
                        bt = bond.GetBondType()
                        if bt == Chem.rdchem.BondType.SINGLE:
                            w = 1.0
                        elif bt == Chem.rdchem.BondType.DOUBLE:
                            w = 2.0
                        elif bt == Chem.rdchem.BondType.TRIPLE:
                            w = 3.0
                        elif bt == Chem.rdchem.BondType.AROMATIC:
                            w = 1.5
                        else:
                            w = 1.0
                        adjacency[i, j] = adjacency[j, i] = w

            return adjacency

        except Exception as e:
            # print(f"Error converting SMILES {smiles} to adjacency: {e}") # Commented to reduce spam
            return np.zeros((self.max_atoms, self.max_atoms))

    def extract_rdkit_descriptors(self, smiles_list):
        descriptor_names = [desc[0] for desc in Descriptors.descList]
        all_descriptors = []
        valid_indices = []

        for i, smiles in enumerate(smiles_list):
            mol = Chem.MolFromSmiles(smiles)
            if mol is not None:
                try:
                    # Filter out NaN/inf descriptors that can arise for some molecules
                    descriptors = [desc_func(mol) for desc_name, desc_func in Descriptors.descList]
                    if all(np.isfinite(d) for d in descriptors):
                        all_descriptors.append(descriptors)
                        valid_indices.append(i)
                    else:
                        # print(f"Skipping molecule {smiles} due to non-finite descriptors.") # Commented to reduce spam
                        pass
                except:
                    # print(f"Skipping molecule {smiles} due to descriptor calculation error.") # Commented to reduce spam
                    pass
            # else:
                # print(f"Skipping invalid SMILES {smiles} for descriptor extraction.") # Commented to reduce spam

        if not all_descriptors:
            return pd.DataFrame(columns=descriptor_names), []

        df_descriptors = pd.DataFrame(all_descriptors, columns=descriptor_names)
        # Handle any remaining NaN/inf by replacing with 0 or mean, or dropping column
        df_descriptors = df_descriptors.replace([np.inf, -np.inf], np.nan).fillna(0) # Simple imputation for now

        return df_descriptors, valid_indices


    def convert_smiles_list(self, smiles_list):
        adjacency_matrices = []
        valid_adj_indices = []

        for i, sm in enumerate(smiles_list):
            if pd.isna(sm):
                continue
            adj = self.smiles_to_adjacency(sm)
            # Only include if the adjacency matrix is not all zeros (implies a valid molecule was processed)
            if not np.all(adj == 0):
                adjacency_matrices.append(adj)
                valid_adj_indices.append(i)

        return adjacency_matrices, valid_adj_indices



# ======================================================================
# 4. MAIN PIPELINE
# ======================================================================
class DrugClassificationPipeline:
    def __init__(self, n_bins=20, max_atoms=100, n_laplacian_eigenvalues=3,
                 test_size=0.2, random_state=42):

        self.n_bins = n_bins
        self.max_atoms = max_atoms
        self.test_size = test_size
        self.random_state = random_state
        self.n_laplacian_eigenvalues = n_laplacian_eigenvalues # Store the parameter

        self.graph_converter = SMILESToGraphConverter(max_atoms = max_atoms)
        # Pass n_laplacian_eigenvalues to DiscriminativeFeatureGenerator
        self.feature_generator = DiscriminativeFeatureGenerator(n_bins=n_bins, n_laplacian_eigenvalues=self.n_laplacian_eigenvalues)

        self.label_encoder = LabelEncoder()
        self.scaler = StandardScaler() # Add a scaler for features
        self.models = {}
        self.results = {}
        self.class_names = None

    # ----------------------------------------------------------
    def load_data(self):
        df = pd.read_csv("drugs_combined.csv")
        return df

    # ----------------------------------------------------------
    def preprocess_data(self, df):
        df_clean = df.dropna(subset=["SMILES", "target"])
        return df_clean

    # ----------------------------------------------------------
    def prepare_features(self, df):
        smiles_list = df["SMILES"].tolist()
        targets = df["target"].tolist()

        # Extract topological features (and their valid indices)
        adjacency_matrices, valid_adj_indices = self.graph_converter.convert_smiles_list(smiles_list)
        # Ensure valid_adj_indices are correctly used for targets and df subset for topological features
        # X_topo will be scaled later if needed
        X_topo, y_topo_filtered, feature_info = self.feature_generator.fit_transform(adjacency_matrices, [targets[i] for i in valid_adj_indices])
        valid_topo_df = df.iloc[valid_adj_indices].reset_index(drop=True)

        # Extract RDKit descriptors (and their valid indices)
        df_rdkit_descriptors, valid_rdkit_indices = self.graph_converter.extract_rdkit_descriptors(smiles_list)
        valid_rdkit_df = df.iloc[valid_rdkit_indices].reset_index(drop=True)

        # Find the common valid indices from both feature sets
        common_indices = sorted(list(set(valid_adj_indices) & set(valid_rdkit_indices)))

        # Filter X_topo and df_rdkit_descriptors based on common_indices
        # Need to re-index df based on common indices to align targets
        final_df = df.iloc[common_indices].reset_index(drop=True)
        final_smiles_list = final_df["SMILES"].tolist()
        final_targets = final_df["target"].tolist()

        # Regenerate topological features for common_indices only
        # This is a bit inefficient, but ensures perfect alignment
        adjacency_matrices_final, _ = self.graph_converter.convert_smiles_list(final_smiles_list)
        X_topo_final, _, feature_info = self.feature_generator.fit_transform(adjacency_matrices_final, final_targets)

        # Regenerate RDKit descriptors for common_indices only
        df_rdkit_descriptors_final, _ = self.graph_converter.extract_rdkit_descriptors(final_smiles_list)

        # Concatenate features
        X_combined = np.hstack((X_topo_final, df_rdkit_descriptors_final.values))

        # Scale features
        X_scaled = self.scaler.fit_transform(X_combined)

        # Encode labels
        if isinstance(final_targets[0], str):
            y_encoded = self.label_encoder.fit_transform(final_targets)
            self.class_names = self.label_encoder.classes_
        else:
            y_encoded = np.array(final_targets)
            self.class_names = sorted(np.unique(final_targets))

        return X_scaled, y_encoded, final_df, feature_info

    # ----------------------------------------------------------
    def train_models(self, X_train, X_test, y_train, y_test):
        # Hyperparameter tuning for Random Forest using RandomizedSearchCV
        rf_param_dist = {
            'n_estimators': [200, 500, 1000, 1500, 2000],
            'max_features': ['auto', 'sqrt', 'log2'],
            'max_depth': [10, 20, 30, 40, None],
            'min_samples_split': [2, 5, 10, 20],
            'min_samples_leaf': [1, 2, 4, 8],
            'bootstrap': [True, False]
        }

        rf = RandomForestClassifier(random_state=42, class_weight='balanced', n_jobs=-1)
        rf_random_search = RandomizedSearchCV(estimator=rf, param_distributions=rf_param_dist,
                                           n_iter=100, cv=5, verbose=1, random_state=42, n_jobs=-1, scoring='roc_auc') # Increased n_iter and cv
        rf_random_search.fit(X_train, y_train)

        best_rf_model = rf_random_search.best_estimator_
        rf_y_pred = best_rf_model.predict(X_test)
        rf_acc = accuracy_score(y_test, rf_y_pred)
        rf_cv_scores = cross_val_score(best_rf_model, X_train, y_train, cv=5, n_jobs=-1, scoring='roc_auc')
        rf_roc_auc = roc_auc_score(y_test, best_rf_model.predict_proba(X_test)[:, 1])

        print(f"\nBest Random Forest Parameters: {rf_random_search.best_params_}")
        print(f"Tuned Random Forest Accuracy = {rf_acc:.4f}, Tuned CV ROC-AUC = {rf_cv_scores.mean():.4f}, Test ROC-AUC = {rf_roc_auc:.4f}")

        # SVM Model (tuning with RandomizedSearchCV)
        svm_param_dist = {
            'C': [0.1, 1, 10, 100],
            'gamma': [1, 0.1, 0.01, 0.001, 'auto', 'scale'],
            'kernel': ['rbf', 'linear']
        }
        svm_model = SVC(probability=True, class_weight="balanced", random_state=42)
        svm_random_search = RandomizedSearchCV(estimator=svm_model, param_distributions=svm_param_dist,
                                             n_iter=50, cv=5, verbose=1, random_state=42, n_jobs=-1, scoring='roc_auc') # Added tuning for SVM
        svm_random_search.fit(X_train, y_train)

        best_svm_model = svm_random_search.best_estimator_
        svm_y_pred = best_svm_model.predict(X_test)
        svm_acc = accuracy_score(y_test, svm_y_pred)
        svm_cv_scores = cross_val_score(best_svm_model, X_train, y_train, cv=5, n_jobs=-1, scoring='roc_auc')
        svm_roc_auc = roc_auc_score(y_test, best_svm_model.predict_proba(X_test)[:, 1])

        print(f"\nBest SVM Parameters: {svm_random_search.best_params_}")
        print(f"Tuned SVM Accuracy = {svm_acc:.4f}, Tuned CV ROC-AUC = {svm_cv_scores.mean():.4f}, Test ROC-AUC = {svm_roc_auc:.4f}")

        # MLP Classifier
        mlp_param_dist = {
            'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50), (100, 100)],
            'activation': ['tanh', 'relu'],
            'solver': ['sgd', 'adam'],
            'alpha': [0.0001, 0.001, 0.01],
            'learning_rate': ['constant', 'adaptive'],
            'max_iter': [200, 500, 1000]
        }

        mlp = MLPClassifier(random_state=42, early_stopping=True)
        mlp_random_search = RandomizedSearchCV(estimator=mlp, param_distributions=mlp_param_dist,
                                            n_iter=50, cv=5, verbose=1, random_state=42, n_jobs=-1, scoring='roc_auc')
        mlp_random_search.fit(X_train, y_train)

        best_mlp_model = mlp_random_search.best_estimator_
        mlp_y_pred = best_mlp_model.predict(X_test)
        mlp_acc = accuracy_score(y_test, mlp_y_pred)
        mlp_cv_scores = cross_val_score(best_mlp_model, X_train, y_train, cv=5, n_jobs=-1, scoring='roc_auc')
        mlp_roc_auc = roc_auc_score(y_test, best_mlp_model.predict_proba(X_test)[:, 1])

        print(f"\nBest MLP Parameters: {mlp_random_search.best_params_}")
        print(f"Tuned MLP Accuracy = {mlp_acc:.4f}, Tuned CV ROC-AUC = {mlp_cv_scores.mean():.4f}, Test ROC-AUC = {mlp_roc_auc:.4f}")


        self.results = {
            "Random Forest": {
                "model": best_rf_model,
                "y_pred": rf_y_pred,
                "accuracy": rf_acc,
                "cv_mean_roc_auc": rf_cv_scores.mean(),
                "cv_std_roc_auc": rf_cv_scores.std(),
                "test_roc_auc": rf_roc_auc,
                "best_params": rf_random_search.best_params_
            },
            "SVM": {
                "model": best_svm_model,
                "y_pred": svm_y_pred,
                "accuracy": svm_acc,
                "cv_mean_roc_auc": svm_cv_scores.mean(),
                "cv_std_roc_auc": svm_cv_scores.std(),
                "test_roc_auc": svm_roc_auc,
                "best_params": svm_random_search.best_params_
            },
            "MLP": {
                "model": best_mlp_model,
                "y_pred": mlp_y_pred,
                "accuracy": mlp_acc,
                "cv_mean_roc_auc": mlp_cv_scores.mean(),
                "cv_std_roc_auc": mlp_cv_scores.std(),
                "test_roc_auc": mlp_roc_auc,
                "best_params": mlp_random_search.best_params_
            }
        }

        self.models = {"Random Forest": best_rf_model, "SVM": best_svm_model, "MLP": best_mlp_model}

    # ----------------------------------------------------------
    def run_pipeline(self):
        df = self.load_data()
        df = self.preprocess_data(df)

        # Scaffold split
        train_idx, test_idx = scaffold_split(df, test_size=self.test_size,
                                             random_state=self.random_state)

        df_train = df.iloc[train_idx].reset_index(drop=True)
        df_test = df.iloc[test_idx].reset_index(drop=True)

        # Prepare features
        # X, y, valid_df from prepare_features now contains all combined features and filtered data
        X_train, y_train, _, _ = self.prepare_features(df_train)
        X_test, y_test, _, _ = self.prepare_features(df_test)

        # Train + evaluate
        self.train_models(X_train, X_test, y_train, y_test)

        return X_train, y_train, X_test,y_test, train_idx, test_idx


if __name__ == "__main__":
    print("=" * 70)
    print("ENHANCED DRUG CLASSIFICATION PIPELINE WITH ADVANCED TOPOLOGY AND RDKIT DESCRIPTORS")
    print("=" * 70)
    print(f"TopoModelX Available: {TOPONETX_AVAILABLE}")

    # Initialize and run pipeline
    pipeline = DrugClassificationPipeline(
        n_bins=15,
        max_atoms=120,
        n_laplacian_eigenvalues=5,  # Setting n_laplacian_eigenvalues to 5 as suggested
        test_size=0.2,
        random_state=42
    )

    print("\nPipeline Configuration:")
    print(f"- Number of filtration steps: {pipeline.n_bins}")
    print(f"- Maximum atoms per molecule: {pipeline.max_atoms}")
    print(f"- 1-Laplacian eigenvalues: {pipeline.n_laplacian_eigenvalues}") # Print the updated parameter

    # Run the complete pipeline
    X_train, y_train, X_test, y_test, train_idx, test_idx = pipeline.run_pipeline()
# Out:
# ...
# ENHANCED DRUG CLASSIFICATION PIPELINE WITH ADVANCED TOPOLOGY
# ...
# TopoModelX Available: False
#
# Pipeline Configuration:
# - Number of filtration steps: 15
# - Maximum atoms per molecule: 120
# - 1-Laplacian eigenvalues: 5
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Random Forest Parameters: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10, 'bootstrap': True}
# Tuned Random Forest Accuracy = 0.7815, Tuned CV = 0.7518
# SVM Accuracy = 0.7610, CV = 0.7371
